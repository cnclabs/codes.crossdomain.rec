# %%
import matplotlib.pyplot as plt

# %%
top_N = [1,3,5,10,20]

# %%
# KK dataset

# %%
## target domain

# %%
# recall
kk_bpr_target_recall = [0.5745, 0.767, 0.8285, 0.8825, 0.909]
kk_cmf_target_recall = [0.2405, 0.332, 0.371, 0.3925, 0.4105]
kk_emcdr_target_recall = [0.3055, 0.51, 0.612, 0.7325, 0.8205]
kk_ddtcdr_target_recall = [0.258, 0.416, 0.506, 0.6185, 0.7245]
kk_cpr_target_recall = [0.786, 0.9125, 0.9385, 0.963, 0.979]

# ndcg
kk_bpr_target_ndcg = [0.5745, 0.6865, 0.7119, 0.7295, 0.7362]
kk_cmf_target_ndcg = [0.2405, 0.2942, 0.3103, 0.3174, 0.3220]
kk_emcdr_target_ndcg = [0.3055, 0.4252, 0.4668, 0.5061, 0.5286]
kk_ddtcdr_target_ndcg = [0.258, 0.3495, 0.3867, 0.4234, 0.4503]
kk_cpr_target_ndcg = [0.786, 0.8609, 0.8716, 0.8798, 0.8838]

# %%
plt.figure(figsize=(10,5))
# recall
plt.plot(top_N, kk_bpr_target_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, kk_cmf_target_recall, 'o-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_target_recall, 'o-', color='r', label='EMCDR')
plt.plot(top_N, kk_ddtcdr_target_recall, 'o-', color='c', label='DDTCDR')
plt.plot(top_N, kk_cpr_target_recall, 'o-', color='m', label='CPR')

plt.title('KK on target domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('top-N recall comparison')
plt.ylabel('value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
# ndcg
plt.plot(top_N, kk_bpr_target_ndcg, 's-', color='b', label='BPR')
plt.plot(top_N, kk_cmf_target_ndcg, 's-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_target_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, kk_ddtcdr_target_ndcg, 's-', color='c', label='DDTCDR')
plt.plot(top_N, kk_cpr_target_ndcg, 's-', color='m', label='CPR')

plt.title('KK on target domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('top-N ndcg comparison')
plt.ylabel('value')
plt.legend()
plt.show()

# %%
## overlap users

# %%
# recall
kk_bpr_overlap_recall = [0.5845, 0.783, 0.847, 0.891, 0.919]
kk_cmf_overlap_recall = [0.378, 0.556, 0.621, 0.701, 0.778]
kk_emcdr_overlap_recall = [0.197, 0.385, 0.485, 0.592, 0.7]
kk_ddtcdr_overlap_recall = [0.231, 0.4475, 0.546, 0.651, 0.734]
kk_cpr_overlap_recall = [0.810, 0.916, 0.945, 0.964, 0.981]

# ndcg
kk_bpr_overlap_ndcg = [0.5845, 0.7024, 0.7288, 0.7433, 0.7505]
kk_cmf_overlap_ndcg = [0.378, 0.482, 0.509, 0.535, 0.555]
kk_emcdr_overlap_ndcg = [0.197, 0.3074, 0.3487, 0.3831, 0.4104]
kk_ddtcdr_overlap_ndcg = [0.231, 0.355, 0.396, 0.43, 0.451]
kk_cpr_overlap_ndcg = [0.810, 0.873, 0.882, 0.891, 0.895]

# %%
plt.figure(figsize=(10,5))
# recall
plt.plot(top_N, kk_bpr_overlap_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, kk_cmf_overlap_recall, 'o-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_overlap_recall, 'o-', color='r', label='EMCDR')
plt.plot(top_N, kk_ddtcdr_overlap_recall, 'o-', color='c', label='DDTCDR')
plt.plot(top_N, kk_cpr_overlap_recall, 'o-', color='m', label='CPR')

plt.title('KK on overlap users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('top-N recall comparison')
plt.ylabel('value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
# ndcg
plt.plot(top_N, kk_bpr_overlap_ndcg, 's-', color='b', label='BPR')
plt.plot(top_N, kk_cmf_overlap_ndcg, 's-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_overlap_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, kk_ddtcdr_overlap_ndcg, 's-', color='c', label='DDTCDR')
plt.plot(top_N, kk_cpr_overlap_ndcg, 's-', color='m', label='CPR')

plt.title('KK on overlap users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('top-N ndcg comparison')
plt.ylabel('value')
plt.legend()
plt.show()

# %%
## cold-start

# %%
# recall
kk_cmf_cold_recall = [0.0135, 0.047, 0.062, 0.086, 0.114]
kk_emcdr_cold_recall = [0.192, 0.348, 0.425, 0.547, 0.672]
kk_cpr_cold_recall = [0.3585, 0.579, 0.7005, 0.8315, 0.9015]

# ndcg
kk_cmf_cold_ndcg = [0.0135, 0.033, 0.0391, 0.0469, 0.0541]
kk_emcdr_cold_ndcg = [0.192, 0.2824, 0.3138, 0.3534, 0.3851]
kk_cpr_cold_ndcg = [0.3585, 0.4862, 0.5361, 0.5785, 0.5963]

# %%
plt.figure(figsize=(10,5))
# recall
plt.plot(top_N, kk_cmf_cold_recall, 'o-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_cold_recall, 'o-', color='r', label='EMCDR')
plt.plot(top_N, kk_cpr_cold_recall, 'o-', color='m', label='CPR')

plt.title('KK on cold-start')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('top-N recall comparison')
plt.ylabel('value')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
# ndcg
plt.plot(top_N, kk_cmf_cold_ndcg, 's-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_cold_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, kk_cpr_cold_ndcg, 's-', color='m', label='CPR')

plt.title('KK on cold-start')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('top-N ndcg comparison')
plt.ylabel('value')
plt.legend()
plt.show()

# %%
## target domain users
plt.figure(figsize=(10,5))
plt.subplot(3,2,1)
# recall
plt.plot(top_N, kk_bpr_target_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, kk_cmf_target_recall, '^-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_target_recall, 's-', color='r', label='EMCDR')
plt.plot(top_N, kk_ddtcdr_target_recall, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, kk_cpr_target_recall, 'D-', color='m', label='CPR')

plt.title('Test on users in the target domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('HR')
plt.legend()
# plt.show()

# plt.figure(figsize=(10,5))
plt.subplot(3,2,2)
# ndcg
plt.plot(top_N, kk_bpr_target_ndcg, 'o-', color='b', label='BPR')
plt.plot(top_N, kk_cmf_target_ndcg, '^-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_target_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, kk_ddtcdr_target_ndcg, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, kk_cpr_target_ndcg, 'D-', color='m', label='CPR')

plt.title('Test on users in the target domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend()
# plt.show()
# ================================================================================================
## overlap users
plt.figure(figsize=(10,5))
plt.subplot(3,2,3)
# recall
plt.plot(top_N, kk_bpr_overlap_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, kk_cmf_overlap_recall, '^-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_overlap_recall, 's-', color='r', label='EMCDR')
plt.plot(top_N, kk_ddtcdr_overlap_recall, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, kk_cpr_overlap_recall, 'D-', color='m', label='CPR')

plt.title('Test on overlapped users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('HR')
plt.legend()
# plt.show()

# plt.figure(figsize=(10,5))
plt.subplot(3,2,4)
# ndcg
plt.plot(top_N, kk_bpr_overlap_ndcg, 'o-', color='b', label='BPR')
plt.plot(top_N, kk_cmf_overlap_ndcg, '^-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_overlap_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, kk_ddtcdr_overlap_ndcg, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, kk_cpr_overlap_ndcg, 'D-', color='m', label='CPR')

plt.title('Test on overlapped users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend()
# plt.show()
# ================================================================================================
## cold-start
plt.figure(figsize=(10,5))
plt.subplot(3,2,5)
# recall
plt.plot(top_N, kk_cmf_cold_recall, '^-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_cold_recall, 's-', color='r', label='EMCDR')
plt.plot(top_N, kk_cpr_cold_recall, 'D-', color='m', label='CPR')

plt.title('Test on cold-start users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('HR')
plt.legend()
# plt.show()

# plt.figure(figsize=(10,5))
plt.subplot(3,2,6)
# ndcg
plt.plot(top_N, kk_cmf_cold_ndcg, '^-', color='g', label='CMF')
plt.plot(top_N, kk_emcdr_cold_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, kk_cpr_cold_ndcg, 'D-', color='m', label='CPR')

plt.title('Test on cold-start users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %% [markdown]
# ## Amazon 1: csj -> hk

# %%
## target domain: hk

# %%
# recall
csj_hk_bpr_target_recall = [0.1122, 0.1905, 0.2402, 0.3045, 0.3967]
csj_hk_cmf_target_recall = [0.095, 0.1605, 0.198, 0.3025, 0.3802]
csj_hk_emcdr_target_recall = [0.1, 0.176, 0.2305, 0.326, 0.444]
csj_hk_ddtcdr_target_recall = [0.06, 0.1355, 0.1902, 0.2982, 0.4395]
csj_hk_cpr_target_recall = [0.1342, 0.238, 0.3045, 0.4142, 0.5447]

# ndcg
csj_hk_bpr_target_ndcg = [0.1122, 0.1575, 0.1780, 0.1987, 0.2218]
csj_hk_cmf_target_ndcg = [0.095, 0.1342, 0.1496, 0.1858, 0.2045]
csj_hk_emcdr_target_ndcg = [0.1, 0.1436, 0.1661, 0.1968, 0.2266]
csj_hk_ddtcdr_target_ndcg = [0.06, 0.1029, 0.1253, 0.1601, 0.1957]
csj_hk_cpr_target_ndcg = [0.1342, 0.1944, 0.2217, 0.2573, 0.2903]

# %%
plt.figure(figsize=(10,5))
# recall
plt.plot(top_N, csj_hk_bpr_target_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, csj_hk_cmf_target_recall, 'o-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_target_recall, 'o-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_ddtcdr_target_recall, 'o-', color='c', label='DDTCDR')
plt.plot(top_N, csj_hk_cpr_target_recall, 'o-', color='m', label='CPR')

plt.title('Testing on users in the target (HK) domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('Hit Ratio')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
# ndcg
plt.plot(top_N, csj_hk_bpr_target_ndcg, 's-', color='b', label='BPR')
plt.plot(top_N, csj_hk_cmf_target_ndcg, 's-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_target_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_ddtcdr_target_ndcg, 's-', color='c', label='DDTCDR')
plt.plot(top_N, csj_hk_cpr_target_ndcg, 's-', color='m', label='CPR')

plt.title('Testing on users in the target (HK) domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %%
## overlap users

# %%
# recall
csj_hk_bpr_overlap_recall = [0.1167, 0.1932, 0.2327, 0.2952, 0.3737]
csj_hk_cmf_overlap_recall = [0.1047, 0.1447, 0.185, 0.313, 0.4077]
csj_hk_emcdr_overlap_recall = [0.076, 0.1405, 0.1802, 0.2837, 0.404]
csj_hk_ddtcdr_overlap_recall = [0.0462, 0.1107, 0.1607, 0.2502, 0.377]
csj_hk_cpr_overlap_recall = [0.1572, 0.2705, 0.3317, 0.4395, 0.5687]

# ndcg
csj_hk_bpr_overlap_ndcg = [0.1167, 0.1612, 0.1774, 0.1977, 0.2175]
csj_hk_cmf_overlap_ndcg = [0.1047, 0.1273, 0.143, 0.184, 0.2087]
csj_hk_emcdr_overlap_ndcg = [0.076, 0.1137, 0.1301, 0.1635, 0.1938]
csj_hk_ddtcdr_overlap_ndcg = [0.0462, 0.083, 0.1035, 0.1322, 0.1642]
csj_hk_cpr_overlap_ndcg = [0.1572, 0.2223, 0.2475, 0.2823, 0.3148]

# %%
plt.figure(figsize=(10,5))
# recall
plt.plot(top_N, csj_hk_bpr_overlap_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, csj_hk_cmf_overlap_recall, 'o-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_overlap_recall, 'o-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_ddtcdr_overlap_recall, 'o-', color='c', label='DDTCDR')
plt.plot(top_N, csj_hk_cpr_overlap_recall, 'o-', color='m', label='CPR')

plt.title('Testing on users in the overlap users (CSJ, HK)')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('Hit Ratio')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
# ndcg
plt.plot(top_N, csj_hk_bpr_overlap_ndcg, 's-', color='b', label='BPR')
plt.plot(top_N, csj_hk_cmf_overlap_ndcg, 's-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_overlap_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_ddtcdr_overlap_ndcg, 's-', color='c', label='DDTCDR')
plt.plot(top_N, csj_hk_cpr_overlap_ndcg, 's-', color='m', label='CPR')

plt.title('Testing on users in the overlap users (CSJ, HK)')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %%
## cold-start

# %%
# recall
csj_hk_cmf_cold_recall = [0.0017, 0.0025, 0.0037, 0.0062, 0.0117]
csj_hk_emcdr_cold_recall = [0.0147, 0.065, 0.1075, 0.1845, 0.3135]
csj_hk_cpr_cold_recall = [0.188, 0.346, 0.4265, 0.549, 0.696]

# ndcg
csj_hk_cmf_cold_ndcg = [0.0017, 0.0021, 0.0026, 0.0034, 0.0048]
csj_hk_emcdr_cold_ndcg = [0.0147, 0.0435, 0.0608, 0.0855, 0.1179]
csj_hk_cpr_cold_ndcg = [0.188, 0.2805, 0.3136, 0.3532, 0.3902]

# %%
plt.figure(figsize=(10,5))
# recall
plt.plot(top_N, csj_hk_cmf_cold_recall, 'o-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_cold_recall, 'o-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_cpr_cold_recall, 'o-', color='m', label='CPR')

plt.title('Testing of the cold-start problem (HK)')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('Hit Ratio')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
# ndcg
plt.plot(top_N, csj_hk_cmf_cold_ndcg, 's-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_cold_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_cpr_cold_ndcg, 's-', color='m', label='CPR')

plt.title('Testing of the cold-start problem (HK)')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend()
plt.show()

# %%
# merge 6 figures to one

# %%
## target scenario
# recall
csj_hk_bpr_target_recall = [0.1122, 0.1905, 0.2402, 0.3045, 0.3967]
csj_hk_cmf_target_recall = [0.01875, 0.0765, 0.17, 0.262, 0.3907]
csj_hk_emcdr_target_recall = [0.066, 0.152, 0.196, 0.2612, 0.3412]
csj_hk_ddtcdr_target_recall = [0.008, 0.0125, 0.0257, 0.103, 0.1882]
csj_hk_cpr_target_recall = [0.1635, 0.2632, 0.3262, 0.423, 0.5465]

# ndcg
csj_hk_bpr_target_ndcg = [0.1122, 0.1575, 0.1780, 0.1987, 0.2218]
csj_hk_cmf_target_ndcg = [0.01875, 0.0505, 0.0891, 0.1198, 0.1526]
csj_hk_emcdr_target_ndcg = [0.066, 0.1163, 0.1344, 0.1555, 0.1756]
csj_hk_ddtcdr_target_ndcg = [0.008, 0.0106, 0.0160, 0.0408, 0.0612]
csj_hk_cpr_target_ndcg = [0.1635, 0.2211, 0.2471, 0.2782, 0.3093]

## overlap scenario
# recall
csj_hk_bpr_overlap_recall = [0.1167, 0.1932, 0.2327, 0.2952, 0.3737]
csj_hk_cmf_overlap_recall = [0.03125, 0.0485, 0.0757, 0.2095, 0.361]
csj_hk_emcdr_overlap_recall = [0.039, 0.084, 0.126, 0.1705, 0.2437]
csj_hk_ddtcdr_overlap_recall = [0.015, 0.0195, 0.0212, 0.0777, 0.148]
csj_hk_cpr_overlap_recall = [0.1472, 0.2497, 0.313, 0.4092, 0.5452]

# ndcg
csj_hk_bpr_overlap_ndcg = [0.1167, 0.1612, 0.1774, 0.1977, 0.2175]
csj_hk_cmf_overlap_ndcg = [0.03125, 0.0416, 0.0527, 0.0949, 0.1333]
csj_hk_emcdr_overlap_ndcg = [0.039, 0.064, 0.0822, 0.0965, 0.1150]
csj_hk_ddtcdr_overlap_ndcg = [0.015, 0.0176, 0.0183, 0.0364, 0.0533]
csj_hk_cpr_overlap_ndcg = [0.1472, 0.2062, 0.2321, 0.2630, 0.2972]

## cold
# recall
csj_hk_cmf_cold_recall = [0, 0, 0, 0, 0.0005]
csj_hk_emcdr_cold_recall = [0.0507, 0.1195, 0.1647, 0.2385, 0.3047]
csj_hk_cpr_cold_recall = [0.2037, 0.348, 0.429, 0.5542, 0.707]

# ndcg
csj_hk_cmf_cold_ndcg = [0, 0, 0, 0, 0.00012]
csj_hk_emcdr_cold_ndcg = [0.0507, 0.0906, 0.1092, 0.1328, 0.1496]
csj_hk_cpr_cold_ndcg = [0.2037, 0.2865, 0.3198, 0.3603, 0.3989]

# %%
## target domain users
plt.figure(figsize=(12,10))
plt.subplot(3,2,1)
# recall
plt.plot(top_N, csj_hk_bpr_target_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, csj_hk_cmf_target_recall, '^-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_target_recall, 's-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_ddtcdr_target_recall, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, csj_hk_cpr_target_recall, 'D-', color='m', label='CPR')

plt.title('Test on users in the target domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('HR')
plt.legend(loc=2)
# plt.show()

# plt.figure(figsize=(10,5))
plt.subplot(3,2,2)
# ndcg
plt.plot(top_N, csj_hk_bpr_target_ndcg, 'o-', color='b', label='BPR')
plt.plot(top_N, csj_hk_cmf_target_ndcg, '^-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_target_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_ddtcdr_target_ndcg, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, csj_hk_cpr_target_ndcg, 'D-', color='m', label='CPR')

plt.title('Test on users in the target domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend(loc=2)
# plt.show()
# ================================================================================================
## overlap users
# plt.figure(figsize=(10,5))
plt.subplot(3,2,3)
# recall
plt.plot(top_N, csj_hk_bpr_overlap_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, csj_hk_cmf_overlap_recall, '^-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_overlap_recall, 's-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_ddtcdr_overlap_recall, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, csj_hk_cpr_overlap_recall, 'D-', color='m', label='CPR')

plt.title('Test on shared users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('HR')
plt.legend(loc=2)
# plt.show()

# plt.figure(figsize=(10,5))
plt.subplot(3,2,4)
# ndcg
plt.plot(top_N, csj_hk_bpr_overlap_ndcg, 'o-', color='b', label='BPR')
plt.plot(top_N, csj_hk_cmf_overlap_ndcg, '^-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_overlap_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_ddtcdr_overlap_ndcg, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, csj_hk_cpr_overlap_ndcg, 'D-', color='m', label='CPR')

plt.title('Test on shared users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend(loc=2)
# plt.show()
# ================================================================================================
## cold-start
# plt.figure(figsize=(10,5))
plt.subplot(3,2,5)
# recall
plt.plot(top_N, csj_hk_cmf_cold_recall, '^-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_cold_recall, 's-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_cpr_cold_recall, 'D-', color='m', label='CPR')

plt.title('Test on cold-start users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('HR')
plt.legend(loc=2)
# plt.show()

# plt.figure(figsize=(10,5))
plt.subplot(3,2,6)
# ndcg
plt.plot(top_N, csj_hk_cmf_cold_ndcg, '^-', color='g', label='CMF')
plt.plot(top_N, csj_hk_emcdr_cold_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, csj_hk_cpr_cold_ndcg, 'D-', color='m', label='CPR')

plt.title('Test on cold-start users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend(loc=2)
plt.tight_layout()
plt.savefig('./figures/CSJ-HK_topN.pdf', format='pdf')
plt.show()

# %% [markdown]
# ## Amazon 2: MT-B

# %%
## =========== target users ===========
# recall
mt_b_bpr_target_recall = [0.2056, 0.3007, 0.3586, 0.4351, 0.5016]
mt_b_cmf_target_recall = [0.1897, 0.2166, 0.2535, 0.3042, 0.3945]
mt_b_emcdr_target_recall = [0.2077, 0.336, 0.387, 0.4412, 0.5067]
mt_b_ddtcdr_target_recall = [0.0075, 0.0228, 0.0455, 0.1036, 0.2031]
mt_b_cpr_target_recall = [0.4331, 0.5892, 0.6481, 0.7276, 0.7983]

# ndcg
mt_b_bpr_target_ndcg = [0.2056, 0.2597, 0.2835, 0.3083, 0.3252]
mt_b_cmf_target_ndcg = [0.1897, 0.2051, 0.2210, 0.2367, 0.2588]
mt_b_emcdr_target_ndcg = [0.2077, 0.2818, 0.3028, 0.3202, 0.3368]
mt_b_ddtcdr_target_ndcg = [0.0075, 0.0161, 0.0255, 0.0439, 0.0689]
mt_b_cpr_target_ndcg = [0.4331, 0.5248, 0.5491, 0.5749, 0.5927]

## =========== overlap users ===========
# recall
mt_b_bpr_overlap_recall = [0.0913, 0.1577, 0.1948, 0.2605, 0.3417]
mt_b_cmf_overlap_recall = [0.06, 0.1281, 0.1556, 0.2117, 0.3466]
mt_b_emcdr_overlap_recall = [0.0046, 0.0135, 0.0228, 0.0473, 0.0976]
mt_b_ddtcdr_overlap_recall = [0.0071, 0.0286, 0.0375, 0.0793, 0.1923]
mt_b_cpr_overlap_recall = [0.3141, 0.4516, 0.5162, 0.6092, 0.7065]

# ndcg
mt_b_bpr_overlap_ndcg = [0.0913, 0.1293, 0.1446, 0.1658, 0.1862]
mt_b_cmf_overlap_ndcg = [0.06, 0.1014, 0.1126, 0.1307, 0.1638]
mt_b_emcdr_overlap_ndcg = [0.0046, 0.0098, 0.0136, 0.0213, 0.034]
mt_b_ddtcdr_overlap_ndcg = [0.0071, 0.0199, 0.0234, 0.0369, 0.065]
mt_b_cpr_overlap_ndcg = [0.3141, 0.3941, 0.4206, 0.4507, 0.4754]

## =========== cold-start users ===========
# recall
mt_b_cmf_cold_recall = [0, 0, 0, 0.000125, 0.000375]
mt_b_emcdr_cold_recall = [0.006, 0.015, 0.0246, 0.0461, 0.0866]
mt_b_cpr_cold_recall = [0.113, 0.2193, 0.284, 0.3922, 0.5163]

# ndcg
mt_b_cmf_cold_ndcg = [0, 0, 0, 0.00003613, 0.00009669]
mt_b_emcdr_cold_ndcg = [0.006, 0.0111, 0.0150, 0.0219, 0.0320]
mt_b_cpr_cold_ndcg = [0.113, 0.1741, 0.2007, 0.2357, 0.2669]

# %%
## target domain users
plt.figure(figsize=(12,10))
plt.subplot(3,2,1)
# recall
plt.plot(top_N, mt_b_bpr_target_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, mt_b_cmf_target_recall, '^-', color='g', label='CMF')
plt.plot(top_N, mt_b_emcdr_target_recall, 's-', color='r', label='EMCDR')
plt.plot(top_N, mt_b_ddtcdr_target_recall, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, mt_b_cpr_target_recall, 'D-', color='m', label='CPR')

plt.title('Test on users in the target domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('HR')
plt.legend(loc=2)
# plt.show()

# plt.figure(figsize=(10,5))
plt.subplot(3,2,2)
# ndcg
plt.plot(top_N, mt_b_bpr_target_ndcg, 'o-', color='b', label='BPR')
plt.plot(top_N, mt_b_cmf_target_ndcg, '^-', color='g', label='CMF')
plt.plot(top_N, mt_b_emcdr_target_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, mt_b_ddtcdr_target_ndcg, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, mt_b_cpr_target_ndcg, 'D-', color='m', label='CPR')

plt.title('Test on users in the target domain')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend(loc=2)
# plt.show()
# ================================================================================================
## overlap users
# plt.figure(figsize=(10,5))
plt.subplot(3,2,3)
# recall
plt.plot(top_N, mt_b_bpr_overlap_recall, 'o-', color='b', label='BPR')
plt.plot(top_N, mt_b_cmf_overlap_recall, '^-', color='g', label='CMF')
plt.plot(top_N, mt_b_emcdr_overlap_recall, 's-', color='r', label='EMCDR')
plt.plot(top_N, mt_b_ddtcdr_overlap_recall, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, mt_b_cpr_overlap_recall, 'D-', color='m', label='CPR')

plt.title('Test on shared users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('HR')
plt.legend(loc=2)
# plt.show()

# plt.figure(figsize=(10,5))
plt.subplot(3,2,4)
# ndcg
plt.plot(top_N, mt_b_bpr_overlap_ndcg, 'o-', color='b', label='BPR')
plt.plot(top_N, mt_b_cmf_overlap_ndcg, '^-', color='g', label='CMF')
plt.plot(top_N, mt_b_emcdr_overlap_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, mt_b_ddtcdr_overlap_ndcg, 'x-', color='c', label='DDTCDR')
plt.plot(top_N, mt_b_cpr_overlap_ndcg, 'D-', color='m', label='CPR')

plt.title('Test on shared users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend(loc=2)
# plt.show()
# ================================================================================================
## cold-start
# plt.figure(figsize=(10,5))
plt.subplot(3,2,5)
# recall
plt.plot(top_N, mt_b_cmf_cold_recall, '^-', color='g', label='CMF')
plt.plot(top_N, mt_b_emcdr_cold_recall, 's-', color='r', label='EMCDR')
plt.plot(top_N, mt_b_cpr_cold_recall, 'D-', color='m', label='CPR')

plt.title('Test on cold-start users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('HR')
plt.legend(loc=2)
# plt.show()

# plt.figure(figsize=(10,5))
plt.subplot(3,2,6)
# ndcg
plt.plot(top_N, mt_b_cmf_cold_ndcg, '^-', color='g', label='CMF')
plt.plot(top_N, mt_b_emcdr_cold_ndcg, 's-', color='r', label='EMCDR')
plt.plot(top_N, mt_b_cpr_cold_ndcg, 'D-', color='m', label='CPR')

plt.title('Test on cold-start users')
plt.xticks(top_N)
plt.grid(True,linestyle = "--",color = 'gray' ,linewidth = '0.3',axis='both')
plt.xlabel('Top-N recommendation')
plt.ylabel('NDCG')
plt.legend(loc=2)
plt.tight_layout()
plt.savefig('./figures/MT-B_topN.pdf', format='pdf')
plt.show()

# %%
import os
os.getcwd()
# Out:
# '/home/wtchiang/CDR_research'
